# %%
import pandas as pd

pd.set_option('display.max_colwidth', None)
pd.set_option('display.max_rows', None)

# %%
base = pd.read_csv('2022-05-13 - whishlist.csv', sep=';', names=['title', 'subtitle', 'author', 'stars','evaluations','price', 'pages', 'publication', 'publisher','lastUpdate','link'])
base.drop(base.index[0], inplace=True)
base['price'] = base['price'].str.replace('not found', '', regex=False)
base.drop_duplicates(keep='first', inplace=True)

# %%
# base.sort_values(by='lastUpdate', ascending=False, inplace=True)
base
# Out:
#                                                                                                                                title  \
# 1                                                                           Design de Interação: Além da Interação Humano-Computador
# 2                                        Estratégia de UX: Técnicas de estratégia de produto para criar soluções digitais inovadoras
# 3                                    Leis da Psicologia Aplicadas a UX: Usando psicologia para projetar produtos e serviços melhores
# 4                                                                          UX Design: Guia definitivo com as melhores práticas de UX
# 5                                           Sprint: How to Solve Big Problems and Test New Ideas in Just Five Days (English Edition)
# 6                                                                                                 Isto é Design Thinking de Serviços
# ...
